# %% [markdown]
# # How to Train YOLOv5 on Custom Objects
#
# This tutorial is based on the [YOLOv5 repository](https://github.com/ultralytics/yolov5) by [Ultralytics](https://www.ultralytics.com/). This notebook shows training on **your own custom objects**. Many thanks to Ultralytics for putting this repository together - we hope that in combination with clean data management tools at Roboflow, this technologoy will become easily accessible to any developer wishing to use computer vision in their projects.
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train YOLOv5](https://blog.roboflow.ai/how-to-train-yolov5-on-a-custom-dataset/), concurrently.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train YOLOv5 on your custom objects. We use a [public blood cell detection dataset](https://public.roboflow.ai/object-detection/bccd), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our detector we take the following steps:
#
# * Install YOLOv5 dependencies
# * Download custom YOLOv5 object detection data
# * Write our YOLOv5 Training configuration
# * Run YOLOv5 training
# * Evaluate YOLOv5 performance
# * Visualize YOLOv5 training data
# * Run YOLOv5 inference on test images
# * Export saved YOLOv5 weights for future inference
#
#
#
# ### **About**
#
# [Roboflow](https://roboflow.com) enables teams to deploy custom computer vision models quickly and accurately. Convert data from to annotation format, assess dataset health, preprocess, augment, and more. It's free for your first 1000 source images.
#
# **Looking for a vision model available via API without hassle? Try Roboflow Train.**
#
# ![Roboflow Wordmark](https://i.imgur.com/dcLNMhV.png)

# %% [markdown]
# #Install Dependencies
#
# _(Remember to choose GPU in Runtime if not already selected. Runtime --> Change Runtime Type --> Hardware accelerator --> GPU)_

# %%
# clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
#!git reset --hard 064365d8683fd002e9ad789c1e91fa3d021b44f0
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16008, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 16008 (delta 22), reused 22 (delta 13), pack-reused 15967
# Receiving objects: 100% (16008/16008), 14.68 MiB | 13.35 MiB/s, done.
# Resolving deltas: 100% (10988/10988), done.
# /content/yolov5

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.5/644.5 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00
# Setup complete. Using torch 2.0.1+cu118 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', major=7, minor=0, total_memory=16150MB, multi_processor_count=80)

# %% [markdown]
# # Download Correctly Formatted Custom Dataset
#
# We'll download our dataset from Roboflow. Use the "**YOLOv5 PyTorch**" export format. Note that the Ultralytics implementation calls for a YAML file defining where your training and test data is. The Roboflow export also writes this format for us.
#
# To get your data into Roboflow, follow the [Getting Started Guide](https://blog.roboflow.ai/getting-started-with-roboflow/).

# %% [markdown]
# ![YOLOv5 PyTorch export](https://i.imgur.com/5vr9G2u.png)

# %%
#follow the link below to get your download code from from Roboflow
# !pip install -q roboflow
#from roboflow import Roboflow
#rf = Roboflow(model_format="yolov5", notebook="roboflow-yolov5")

# %%
# %cd /content/yolov5
#after following the link above, recieve python code with these fields filled in
from roboflow import Roboflow
rf = Roboflow(api_key="URcqXSgsUrEvOqg24tdD")
project = rf.workspace("tectonia-azmbv").project("contrainer-damage-detection")
dataset = project.version(3).download("yolov5")
# Out:
# /content/yolov5
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Contrainer-Damage-Detection-3 to yolov5pytorch:: 100%|██████████| 43955/43955 [00:00<00:00, 48629.08it/s]
# Extracting Dataset Version Zip to Contrainer-Damage-Detection-3 in yolov5pytorch:: 100%|██████████| 1822/1822 [00:00<00:00, 7896.11it/s]

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat {dataset.location}/data.yaml
# Out:
# names:
# - Deframe_or_Dent
# - Hole
# - Rust
# nc: 3
# roboflow:
#   license: CC BY 4.0
#   project: contrainer-damage-detection
#   url: https://universe.roboflow.com/tectonia-azmbv/contrainer-damage-detection/dataset/3
#   version: 3
#   workspace: tectonia-azmbv
# test: ../test/images
# train: Contrainer-Damage-Detection-3/train/images
# val: Contrainer-Damage-Detection-3/valid/images

# %% [markdown]
# # Define Model Configuration and Architecture
#
# We will write a yaml script that defines the parameters for our model like the number of classes, anchors, and each layer.
#
# You do not need to edit these cells, but you may.

# %%
# define number of classes based on YAML
import yaml
with open(dataset.location + "/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
#this is the model configuration we will use for our tutorial
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, AGPL-3.0 license
#
# # Parameters
# nc: 80  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 640 --batch 16 --epochs 300 --data {dataset.location}/data.yaml --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# /content/yolov5
# train: weights=, cfg=./models/custom_yolov5s.yaml, data=/content/yolov5/Contrainer-Damage-Detection-3/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-227-ge4df1ec Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 22.2MB/s]
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  3    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     21576  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# custom_YOLOv5s summary: 233 layers, 7260488 parameters, 7260488 gradients
#
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 59 weight(decay=0.0), 70 weight(decay=0.0005), 62 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/yolov5/Contrainer-Damage-Detection-3/train/labels... 790 images, 3 backgrounds, 0 corrupt: 100% 790/790 [00:00<00:00, 6987.06it/s]
# train: New cache created: /content/yolov5/Contrainer-Damage-Detection-3/train/labels.cache
# train: Caching images (0.9GB ram): 100% 790/790 [00:00<00:00, 980.14it/s]
# val: Scanning /content/yolov5/Contrainer-Damage-Detection-3/valid/labels... 77 images, 0 backgrounds, 0 corrupt: 100% 77/77 [00:00<00:00, 1983.16it/s]
# val: New cache created: /content/yolov5/Contrainer-Damage-Detection-3/valid/labels.cache
# val: Caching images (0.1GB ram): 100% 77/77 [00:00<00:00, 317.86it/s]
#
# AutoAnchor: 4.54 anchors/target, 0.996 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/yolov5s_results/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/yolov5s_results
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/299      3.88G     0.1036    0.03822    0.03747         27        640: 100% 50/50 [00:09<00:00,  5.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.34it/s]
#                    all         77        167   0.000534      0.122   0.000407   9.71e-05
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/299      4.46G    0.09656    0.03834    0.03621         22        640: 100% 50/50 [00:04<00:00, 10.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  4.66it/s]
#                    all         77        167   0.000274     0.0627   0.000212    4.9e-05
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/299      4.46G    0.09412    0.03731    0.03482         42        640: 100% 50/50 [00:04<00:00, 10.91it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  4.25it/s]
#                    all         77        167     0.0112     0.0198     0.0016   0.000375
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/299      4.46G    0.09129    0.03717    0.03306         25        640: 100% 50/50 [00:04<00:00, 11.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.32it/s]
#                    all         77        167      0.339     0.0132   0.000882     0.0002
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/299      4.46G     0.0901    0.03657    0.03072         25        640: 100% 50/50 [00:04<00:00, 11.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.07it/s]
#                    all         77        167    0.00211      0.174    0.00773    0.00453
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/299      4.46G    0.08908    0.03901    0.02828         14        640: 100% 50/50 [00:04<00:00, 11.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.78it/s]
#                    all         77        167    0.00468      0.255     0.0426     0.0131
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/299      4.46G    0.08824    0.03787    0.02732         32        640: 100% 50/50 [00:04<00:00, 11.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.81it/s]
#                    all         77        167    0.00294      0.294     0.0209    0.00469
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/299      4.46G    0.08742    0.03599    0.02563         20        640: 100% 50/50 [00:04<00:00, 11.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.46it/s]
#                    all         77        167      0.693     0.0303     0.0188    0.00417
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/299      4.46G    0.08616    0.03539    0.02449         31        640: 100% 50/50 [00:04<00:00, 11.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  4.92it/s]
#                    all         77        167      0.787      0.101     0.0778     0.0256
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/299      4.46G    0.08532    0.03689    0.02482         17        640: 100% 50/50 [00:04<00:00, 11.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  4.49it/s]
#                    all         77        167      0.797      0.121     0.0651     0.0186
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/299      4.46G    0.08436    0.03866     0.0236         28        640: 100% 50/50 [00:04<00:00, 11.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.23it/s]
#                    all         77        167      0.751      0.121     0.0536     0.0173
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/299      4.46G    0.08273    0.03818    0.02378         29        640: 100% 50/50 [00:04<00:00, 11.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.43it/s]
#                    all         77        167      0.782      0.111     0.0656     0.0198
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/299      4.46G    0.08213    0.03746    0.02334         35        640: 100% 50/50 [00:04<00:00, 11.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.32it/s]
#                    all         77        167      0.846     0.0808     0.0827     0.0256
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/299      4.46G    0.08135     0.0374    0.02336         18        640: 100% 50/50 [00:04<00:00, 11.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.29it/s]
#                    all         77        167      0.864      0.141      0.118     0.0379
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/299      4.46G    0.08088    0.03946      0.023         19        640: 100% 50/50 [00:04<00:00, 10.89it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  4.95it/s]
#                    all         77        167      0.908      0.131      0.141     0.0458
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/299      4.46G    0.07908    0.03957    0.02281         18        640: 100% 50/50 [00:04<00:00, 11.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.72it/s]
#                    all         77        167      0.799      0.162      0.115     0.0377
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/299      4.46G    0.07771    0.03847    0.02139         11        640: 100% 50/50 [00:04<00:00, 11.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.47it/s]
#                    all         77        167      0.815      0.152      0.112     0.0347
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/299      4.46G     0.0776     0.0382    0.02167         15        640: 100% 50/50 [00:04<00:00, 10.83it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.11it/s]
#                    all         77        167      0.856      0.147       0.14     0.0433
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/299      4.46G    0.07742    0.03984    0.02064         20        640: 100% 50/50 [00:04<00:00, 10.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.12it/s]
#                    all         77        167      0.824      0.111     0.0913     0.0269
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/299      4.46G    0.07639    0.03901    0.01996         21        640: 100% 50/50 [00:04<00:00, 11.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.39it/s]
#                    all         77        167      0.784      0.154     0.0836     0.0282
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/299      4.46G    0.07611    0.03898    0.02063         29        640: 100% 50/50 [00:04<00:00, 11.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.27it/s]
#                    all         77        167      0.828      0.162      0.118     0.0397
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/299      4.46G    0.07434    0.03878    0.01936         17        640: 100% 50/50 [00:04<00:00, 10.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.19it/s]
#                    all         77        167      0.845      0.121      0.107     0.0309
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/299      4.46G    0.07393    0.03858    0.01873         20        640: 100% 50/50 [00:04<00:00, 11.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.00it/s]
#                    all         77        167      0.864      0.131      0.143     0.0488
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/299      4.46G     0.0738     0.0387    0.01836         28        640: 100% 50/50 [00:04<00:00, 10.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.33it/s]
#                    all         77        167      0.766      0.145      0.168     0.0483
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/299      4.46G    0.07385    0.03999     0.0186         18        640: 100% 50/50 [00:04<00:00, 11.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  4.90it/s]
#                    all         77        167      0.757      0.178      0.177     0.0554
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/299      4.46G     0.0727    0.03978     0.0164         22        640: 100% 50/50 [00:04<00:00, 11.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  4.57it/s]
#                    all         77        167      0.345      0.135      0.103     0.0384
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/299      4.46G    0.07212    0.03941    0.01669         17        640: 100% 50/50 [00:04<00:00, 10.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  4.67it/s]
#                    all         77        167      0.607      0.168       0.16     0.0612
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/299      4.46G    0.07084    0.03915    0.01542         32        640: 100% 50/50 [00:04<00:00, 11.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  4.20it/s]
#                    all         77        167      0.921      0.141      0.173     0.0552
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/299      4.46G    0.07032    0.03822    0.01553         22        640: 100% 50/50 [00:04<00:00, 10.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.08it/s]
#                    all         77        167      0.872      0.179      0.193     0.0699
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/299      4.46G    0.07012    0.03887     0.0149         20        640: 100% 50/50 [00:04<00:00, 11.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  4.72it/s]
#                    all         77        167       0.21      0.193      0.139     0.0448
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/299      4.46G    0.06835    0.03824    0.01314         21        640: 100% 50/50 [00:04<00:00, 10.93it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.14it/s]
#                    all         77        167      0.465      0.152     0.0997     0.0317
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/299      4.46G    0.06851    0.03756    0.01456         15        640: 100% 50/50 [00:04<00:00, 11.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.57it/s]
#                    all         77        167       0.82      0.101      0.123     0.0431
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      32/299      4.46G    0.06911    0.03763    0.01273         24        640: 100% 50/50 [00:04<00:00, 10.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.53it/s]
#                    all         77        167      0.921      0.162      0.239     0.0851
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      33/299      4.46G    0.06806    0.03731    0.01228         35        640: 100% 50/50 [00:04<00:00, 10.89it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  4.79it/s]
#                    all         77        167      0.363      0.215      0.196     0.0579
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      34/299      4.46G    0.06681    0.03676    0.01203         27        640: 100% 50/50 [00:04<00:00, 10.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.42it/s]
#                    all         77        167      0.657      0.188      0.224     0.0746
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      35/299      4.46G    0.06689    0.03691    0.01132         23        640: 100% 50/50 [00:04<00:00, 10.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.51it/s]
#                    all         77        167      0.329      0.237      0.241     0.0971
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      36/299      4.46G     0.0657    0.03675    0.01119         10        640: 100% 50/50 [00:04<00:00, 11.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.56it/s]
#                    all         77        167      0.294      0.287      0.236     0.0702
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      37/299      4.46G     0.0654    0.03602    0.01123         27        640: 100% 50/50 [00:04<00:00, 10.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.50it/s]
#                    all         77        167      0.263      0.319      0.229     0.0884
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      38/299      4.46G    0.06441    0.03667     0.0106         16        640: 100% 50/50 [00:04<00:00, 11.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.69it/s]
#                    all         77        167      0.271       0.32      0.264     0.0962
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      39/299      4.46G    0.06559    0.03658    0.01124         28        640: 100% 50/50 [00:04<00:00, 10.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.17it/s]
#                    all         77        167      0.236       0.31      0.284     0.0971
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      40/299      4.46G    0.06292    0.03613   0.009711         17        640: 100% 50/50 [00:04<00:00, 11.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.68it/s]
#                    all         77        167      0.369      0.226      0.249     0.0859
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      41/299      4.46G    0.06326    0.03699   0.009322         20        640: 100% 50/50 [00:04<00:00, 10.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.32it/s]
#                    all         77        167      0.474      0.303        0.3      0.115
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      42/299      4.46G     0.0626    0.03575   0.008929         24        640: 100% 50/50 [00:04<00:00, 10.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.78it/s]
#                    all         77        167      0.341      0.373      0.308     0.0862
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      43/299      4.46G    0.06262    0.03659   0.008459         17        640: 100% 50/50 [00:04<00:00, 10.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.59it/s]
#                    all         77        167      0.516      0.377      0.387      0.148
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      44/299      4.46G    0.06199    0.03612   0.007727         22        640: 100% 50/50 [00:04<00:00, 11.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.93it/s]
#                    all         77        167      0.446      0.319      0.324      0.119
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      45/299      4.46G    0.06122     0.0353    0.00804         29        640: 100% 50/50 [00:04<00:00, 10.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.49it/s]
#                    all         77        167      0.387      0.416      0.343      0.113
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      46/299      4.46G    0.06027     0.0353   0.008601         38        640: 100% 50/50 [00:04<00:00, 10.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.60it/s]
#                    all         77        167      0.397      0.349      0.329      0.111
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      47/299      4.46G    0.06127    0.03534   0.008643         19        640: 100% 50/50 [00:04<00:00, 10.99it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.81it/s]
#                    all         77        167      0.388      0.306      0.284      0.105
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      48/299      4.46G    0.05986     0.0336   0.008308         14        640: 100% 50/50 [00:04<00:00, 10.91it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.98it/s]
#                    all         77        167      0.579      0.303        0.3      0.101
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      49/299      4.46G    0.05985    0.03364   0.007657         14        640: 100% 50/50 [00:04<00:00, 10.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.92it/s]
#                    all         77        167      0.292      0.326      0.287       0.11
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      50/299      4.46G    0.05933    0.03368   0.007127         18        640: 100% 50/50 [00:04<00:00, 11.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.61it/s]
#                    all         77        167      0.506       0.43      0.409      0.142
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      51/299      4.46G    0.05799    0.03489   0.006624         18        640: 100% 50/50 [00:04<00:00, 10.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.74it/s]
#                    all         77        167      0.573      0.405      0.398      0.151
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      52/299      4.46G    0.05733      0.034   0.006405         25        640: 100% 50/50 [00:04<00:00, 11.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.86it/s]
#                    all         77        167      0.457      0.397      0.389      0.143
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      53/299      4.46G     0.0579    0.03425   0.006527         28        640: 100% 50/50 [00:04<00:00, 11.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.10it/s]
#                    all         77        167       0.55      0.421      0.412      0.139
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      54/299      4.46G    0.05755    0.03375   0.006502         28        640: 100% 50/50 [00:04<00:00, 11.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.15it/s]
#                    all         77        167      0.553      0.403      0.396      0.141
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      55/299      4.46G    0.05678    0.03304   0.006345         17        640: 100% 50/50 [00:04<00:00, 10.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  4.92it/s]
#                    all         77        167      0.502       0.39      0.409      0.155
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      56/299      4.46G    0.05651    0.03472   0.006255         37        640: 100% 50/50 [00:04<00:00, 11.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.49it/s]
#                    all         77        167      0.471      0.427      0.421      0.151
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      57/299      4.46G    0.05629    0.03429   0.005574         43        640: 100% 50/50 [00:04<00:00, 10.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.59it/s]
#                    all         77        167      0.529       0.45      0.446      0.171
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      58/299      4.46G    0.05501    0.03354   0.005074         24        640: 100% 50/50 [00:04<00:00, 10.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.69it/s]
#                    all         77        167      0.676      0.409      0.441      0.151
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      59/299      4.46G    0.05485     0.0329   0.005242         22        640: 100% 50/50 [00:04<00:00, 11.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.34it/s]
#                    all         77        167      0.571      0.393      0.424      0.155
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      60/299      4.46G    0.05465    0.03296   0.005393         33        640: 100% 50/50 [00:04<00:00, 10.97it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.92it/s]
#                    all         77        167      0.543      0.472      0.463      0.167
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      61/299      4.46G    0.05258    0.03292   0.005506         23        640: 100% 50/50 [00:04<00:00, 10.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.16it/s]
#                    all         77        167      0.651      0.421      0.448      0.166
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      62/299      4.46G    0.05326    0.03253   0.004825         35        640: 100% 50/50 [00:04<00:00, 10.45it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.94it/s]
#                    all         77        167      0.646       0.44      0.467       0.16
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      63/299      4.46G    0.05325     0.0324   0.004997         24        640: 100% 50/50 [00:04<00:00, 10.93it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.00it/s]
#                    all         77        167      0.595       0.49      0.479      0.176
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      64/299      4.46G    0.05321    0.03283   0.004573         21        640: 100% 50/50 [00:04<00:00, 10.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.35it/s]
#                    all         77        167      0.594      0.462      0.479      0.166
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      65/299      4.46G    0.05244    0.03153    0.00474         33        640: 100% 50/50 [00:04<00:00, 11.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.54it/s]
#                    all         77        167      0.568      0.455      0.497      0.176
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      66/299      4.46G    0.05301    0.03083   0.004437         18        640: 100% 50/50 [00:04<00:00, 11.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.46it/s]
#                    all         77        167      0.647      0.446      0.464       0.17
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      67/299      4.46G    0.05162    0.03151   0.004527         24        640: 100% 50/50 [00:04<00:00, 10.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.81it/s]
#                    all         77        167      0.625      0.411      0.452      0.182
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      68/299      4.46G    0.05084    0.03101   0.004945         25        640: 100% 50/50 [00:04<00:00, 11.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.32it/s]
#                    all         77        167      0.675       0.45      0.499      0.184
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      69/299      4.46G    0.05106    0.03071   0.005014         29        640: 100% 50/50 [00:04<00:00, 10.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.13it/s]
#                    all         77        167      0.677      0.416      0.452      0.185
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      70/299      4.46G    0.05094    0.03272   0.005168         27        640: 100% 50/50 [00:04<00:00, 11.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.14it/s]
#                    all         77        167      0.648      0.403      0.446      0.158
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      71/299      4.46G    0.05022    0.03134   0.004601         13        640: 100% 50/50 [00:04<00:00, 11.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.34it/s]
#                    all         77        167      0.602      0.503      0.508      0.203
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      72/299      4.46G    0.05021    0.03138   0.003982         23        640: 100% 50/50 [00:04<00:00, 11.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.78it/s]
#                    all         77        167      0.694      0.483       0.52      0.211
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      73/299      4.46G    0.04908    0.03043   0.004665         11        640: 100% 50/50 [00:04<00:00, 11.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.37it/s]
#                    all         77        167      0.674       0.45      0.484      0.198
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      74/299      4.46G    0.04918    0.03039   0.004363         23        640: 100% 50/50 [00:04<00:00, 11.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.42it/s]
#                    all         77        167      0.607      0.471      0.474      0.188
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      75/299      4.46G     0.0488    0.03052   0.004206         25        640: 100% 50/50 [00:04<00:00, 11.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.08it/s]
#                    all         77        167      0.776       0.45      0.545      0.225
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      76/299      4.46G    0.04866    0.03006   0.003699         16        640: 100% 50/50 [00:04<00:00, 11.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.50it/s]
#                    all         77        167      0.727      0.456      0.501      0.199
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      77/299      4.46G     0.0491    0.02955   0.004115         25        640: 100% 50/50 [00:04<00:00, 11.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.93it/s]
#                    all         77        167      0.672      0.523      0.535      0.208
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      78/299      4.46G    0.04822    0.03036   0.003716         30        640: 100% 50/50 [00:04<00:00, 11.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.25it/s]
#                    all         77        167      0.679      0.512       0.53      0.208
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      79/299      4.46G    0.04732    0.03018   0.004026         18        640: 100% 50/50 [00:04<00:00, 11.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.42it/s]
#                    all         77        167      0.681        0.5      0.523      0.221
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      80/299      4.46G     0.0482    0.03038   0.004186         33        640: 100% 50/50 [00:04<00:00, 10.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.83it/s]
#                    all         77        167      0.601      0.505      0.551      0.215
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      81/299      4.46G    0.04792    0.02845   0.003928         21        640: 100% 50/50 [00:04<00:00, 10.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.48it/s]
#                    all         77        167      0.654       0.49       0.52      0.212
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      82/299      4.46G    0.04696    0.02903    0.00399         30        640: 100% 50/50 [00:04<00:00, 11.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.46it/s]
#                    all         77        167      0.701       0.47      0.522      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      83/299      4.46G    0.04677    0.02965   0.003756         13        640: 100% 50/50 [00:04<00:00, 10.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.34it/s]
#                    all         77        167      0.707      0.441      0.489      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      84/299      4.46G    0.04633    0.02944    0.00352         25        640: 100% 50/50 [00:04<00:00, 11.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.95it/s]
#                    all         77        167      0.708      0.504      0.537      0.226
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      85/299      4.46G    0.04562    0.02934   0.003501         29        640: 100% 50/50 [00:04<00:00, 10.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.43it/s]
#                    all         77        167      0.739      0.509      0.536      0.225
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      86/299      4.46G    0.04673    0.02803    0.00401         13        640: 100% 50/50 [00:04<00:00, 11.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.01it/s]
#                    all         77        167      0.739       0.51      0.513       0.23
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      87/299      4.46G     0.0453    0.02848   0.003348         18        640: 100% 50/50 [00:04<00:00, 11.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.21it/s]
#                    all         77        167      0.677      0.527      0.548      0.231
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      88/299      4.46G     0.0452    0.02873   0.003487         29        640: 100% 50/50 [00:04<00:00, 11.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.79it/s]
#                    all         77        167      0.733      0.538      0.572      0.259
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      89/299      4.46G    0.04535    0.02822    0.00346         21        640: 100% 50/50 [00:04<00:00, 11.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.49it/s]
#                    all         77        167      0.682      0.507      0.535      0.235
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      90/299      4.46G    0.04557    0.02775   0.003525         15        640: 100% 50/50 [00:04<00:00, 11.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.31it/s]
#                    all         77        167      0.723      0.493      0.528      0.223
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      91/299      4.46G     0.0447    0.02904   0.003352         37        640: 100% 50/50 [00:04<00:00, 11.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.62it/s]
#                    all         77        167      0.788      0.552      0.598      0.265
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      92/299      4.46G    0.04487     0.0283   0.003541         28        640: 100% 50/50 [00:04<00:00, 11.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.30it/s]
#                    all         77        167      0.787      0.509      0.555      0.268
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      93/299      4.46G    0.04419    0.02785   0.003214         28        640: 100% 50/50 [00:04<00:00, 11.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.07it/s]
#                    all         77        167      0.732      0.515      0.573      0.259
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      94/299      4.46G    0.04338    0.02724   0.003006         15        640: 100% 50/50 [00:04<00:00, 11.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.38it/s]
#                    all         77        167      0.811      0.533      0.577      0.275
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      95/299      4.46G    0.04363     0.0275   0.003335         20        640: 100% 50/50 [00:04<00:00, 10.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.89it/s]
#                    all         77        167      0.809       0.55      0.586      0.246
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      96/299      4.46G    0.04354    0.02793   0.002732         28        640: 100% 50/50 [00:04<00:00, 11.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.58it/s]
#                    all         77        167      0.739      0.523      0.557      0.258
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      97/299      4.46G    0.04287    0.02733   0.002834         23        640: 100% 50/50 [00:04<00:00, 10.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.81it/s]
#                    all         77        167      0.661      0.529      0.532      0.261
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      98/299      4.46G    0.04255    0.02779   0.002992         19        640: 100% 50/50 [00:04<00:00, 11.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.53it/s]
#                    all         77        167      0.629      0.542      0.571      0.271
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      99/299      4.46G    0.04321    0.02663   0.002833         27        640: 100% 50/50 [00:04<00:00, 11.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.70it/s]
#                    all         77        167      0.686      0.544      0.566      0.265
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     100/299      4.46G    0.04249    0.02787   0.003671         35        640: 100% 50/50 [00:04<00:00, 11.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.53it/s]
#                    all         77        167      0.733      0.551      0.563      0.275
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     101/299      4.46G    0.04252    0.02708   0.003329         26        640: 100% 50/50 [00:04<00:00, 11.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.26it/s]
#                    all         77        167      0.788      0.525      0.567      0.244
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     102/299      4.46G    0.04183    0.02741   0.002943         39        640: 100% 50/50 [00:04<00:00, 10.91it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.39it/s]
#                    all         77        167      0.806       0.58      0.605      0.268
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     103/299      4.46G    0.04244    0.02521   0.003129         15        640: 100% 50/50 [00:04<00:00, 10.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.31it/s]
# ...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     263/299      4.46G    0.02597    0.01709  0.0008918          6        640: 100% 50/50 [00:04<00:00, 10.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.39it/s]
#                    all         77        167       0.78       0.64      0.638      0.425
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     264/299      4.46G    0.02587    0.01744  0.0008589         13        640: 100% 50/50 [00:04<00:00, 10.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.61it/s]
#                    all         77        167      0.811      0.635      0.638      0.415
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     265/299      4.46G    0.02581     0.0178  0.0009031         20        640: 100% 50/50 [00:04<00:00, 11.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.71it/s]
#                    all         77        167      0.783      0.644      0.647      0.412
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     266/299      4.46G    0.02604    0.01783   0.001227         20        640: 100% 50/50 [00:04<00:00, 11.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.56it/s]
#                    all         77        167      0.788       0.63      0.648      0.431
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     267/299      4.46G    0.02616    0.01762   0.001071         27        640: 100% 50/50 [00:04<00:00, 10.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.33it/s]
#                    all         77        167      0.823       0.63      0.649      0.412
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     268/299      4.46G     0.0253    0.01746  0.0009261         22        640: 100% 50/50 [00:04<00:00, 11.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.48it/s]
#                    all         77        167      0.812       0.63      0.648      0.411
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     269/299      4.46G    0.02571    0.01727   0.001021         27        640: 100% 50/50 [00:04<00:00, 11.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.88it/s]
#                    all         77        167      0.816      0.633      0.641      0.409
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     270/299      4.46G    0.02538    0.01662  0.0009328         32        640: 100% 50/50 [00:04<00:00, 11.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.76it/s]
#                    all         77        167      0.832      0.627      0.647      0.426
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     271/299      4.46G    0.02539    0.01731  0.0008765         27        640: 100% 50/50 [00:04<00:00, 11.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.67it/s]
#                    all         77        167       0.81      0.644       0.66      0.417
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     272/299      4.46G    0.02598     0.0176  0.0008478         25        640: 100% 50/50 [00:04<00:00, 11.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.01it/s]
#                    all         77        167      0.767      0.644      0.659      0.414
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     273/299      4.46G    0.02567    0.01664  0.0008561         37        640: 100% 50/50 [00:04<00:00, 11.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.47it/s]
#                    all         77        167      0.755      0.644      0.651      0.421
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     274/299      4.46G    0.02488    0.01718   0.001029         32        640: 100% 50/50 [00:04<00:00, 10.97it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.49it/s]
#                    all         77        167      0.802      0.618      0.653       0.42
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     275/299      4.46G    0.02576    0.01661  0.0007255         20        640: 100% 50/50 [00:04<00:00, 11.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.58it/s]
#                    all         77        167      0.774      0.669      0.662      0.426
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     276/299      4.46G    0.02518    0.01639  0.0009763         14        640: 100% 50/50 [00:04<00:00, 11.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.33it/s]
#                    all         77        167      0.814      0.628      0.658      0.425
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     277/299      4.46G     0.0252    0.01666  0.0008485         26        640: 100% 50/50 [00:04<00:00, 11.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.59it/s]
#                    all         77        167      0.799      0.649      0.657      0.429
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     278/299      4.46G    0.02489    0.01696  0.0008859         18        640: 100% 50/50 [00:04<00:00, 11.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.67it/s]
#                    all         77        167      0.795      0.627      0.649      0.425
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     279/299      4.46G    0.02441    0.01716  0.0007743         45        640: 100% 50/50 [00:04<00:00, 11.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.84it/s]
#                    all         77        167      0.768      0.634      0.647      0.416
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     280/299      4.46G    0.02505    0.01716   0.001203         23        640: 100% 50/50 [00:04<00:00, 11.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.34it/s]
#                    all         77        167      0.738      0.666      0.655      0.426
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     281/299      4.46G    0.02486    0.01756  0.0008539         36        640: 100% 50/50 [00:04<00:00, 11.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.48it/s]
#                    all         77        167       0.77      0.636      0.651      0.426
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     282/299      4.46G    0.02493    0.01754   0.000899         25        640: 100% 50/50 [00:04<00:00, 11.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.42it/s]
#                    all         77        167      0.769      0.645       0.65      0.429
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     283/299      4.46G    0.02488    0.01645  0.0007585         18        640: 100% 50/50 [00:04<00:00, 10.93it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.54it/s]
#                    all         77        167      0.787      0.641      0.647      0.433
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     284/299      4.46G    0.02463    0.01645  0.0008214         23        640: 100% 50/50 [00:04<00:00, 11.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.30it/s]
#                    all         77        167      0.782      0.651      0.663      0.434
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     285/299      4.46G     0.0248    0.01722   0.001019         30        640: 100% 50/50 [00:04<00:00, 11.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.60it/s]
#                    all         77        167      0.821      0.642      0.653      0.432
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     286/299      4.46G    0.02393    0.01609  0.0007307         24        640: 100% 50/50 [00:04<00:00, 11.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.59it/s]
#                    all         77        167      0.815      0.643       0.66      0.435
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     287/299      4.46G    0.02423    0.01754  0.0009742         22        640: 100% 50/50 [00:04<00:00, 11.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  5.74it/s]
#                    all         77        167      0.812      0.646      0.653      0.434
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     288/299      4.46G     0.0244    0.01686  0.0007493         19        640: 100% 50/50 [00:04<00:00, 11.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.46it/s]
#                    all         77        167      0.803       0.63      0.654      0.425
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     289/299      4.46G    0.02527    0.01716  0.0009515         17        640: 100% 50/50 [00:04<00:00, 11.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.64it/s]
#                    all         77        167      0.811      0.626      0.647      0.425
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     290/299      4.46G    0.02429    0.01677  0.0009169         31        640: 100% 50/50 [00:04<00:00, 11.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.57it/s]
#                    all         77        167      0.815      0.625      0.648      0.433
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     291/299      4.46G    0.02473    0.01744  0.0008681         44        640: 100% 50/50 [00:04<00:00, 11.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.40it/s]
#                    all         77        167      0.783       0.65      0.652      0.438
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     292/299      4.46G    0.02428    0.01639  0.0008001         22        640: 100% 50/50 [00:04<00:00, 10.99it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.33it/s]
#                    all         77        167      0.773      0.652      0.657      0.431
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     293/299      4.46G    0.02469     0.0164  0.0008313         20        640: 100% 50/50 [00:04<00:00, 11.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.57it/s]
#                    all         77        167      0.767      0.651      0.655      0.432
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     294/299      4.46G    0.02363    0.01653  0.0007735         15        640: 100% 50/50 [00:04<00:00, 11.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.05it/s]
#                    all         77        167      0.771      0.653      0.654      0.425
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     295/299      4.46G    0.02407    0.01632  0.0007745         31        640: 100% 50/50 [00:04<00:00, 11.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.61it/s]
#                    all         77        167      0.796      0.643      0.653      0.423
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     296/299      4.46G    0.02328    0.01635  0.0009034         19        640: 100% 50/50 [00:04<00:00, 11.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.38it/s]
#                    all         77        167      0.802      0.639      0.654      0.421
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     297/299      4.46G    0.02499    0.01728   0.001088         36        640: 100% 50/50 [00:04<00:00, 11.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.11it/s]
#                    all         77        167      0.794      0.645      0.653      0.431
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     298/299      4.46G    0.02401    0.01656   0.000964         36        640: 100% 50/50 [00:04<00:00, 10.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.39it/s]
#                    all         77        167      0.792      0.645      0.655      0.426
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     299/299      4.46G    0.02467    0.01626   0.001033         18        640: 100% 50/50 [00:04<00:00, 10.89it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  6.77it/s]
#                    all         77        167      0.808      0.641      0.655      0.431
#
# 300 epochs completed in 0.453 hours.
# Optimizer stripped from runs/train/yolov5s_results/weights/last.pt, 14.9MB
# Optimizer stripped from runs/train/yolov5s_results/weights/best.pt, 14.9MB
#
# Validating runs/train/yolov5s_results/weights/best.pt...
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7251912 parameters, 0 gradients
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.95it/s]
#                    all         77        167      0.794      0.646      0.651      0.438
#        Deframe_or_Dent         77        101      0.688      0.501      0.511      0.337
#                   Hole         77         33      0.829      0.848      0.827      0.575
#                   Rust         77         33      0.866      0.589      0.616      0.402
# Results saved to runs/train/yolov5s_results
# CPU times: user 21.7 s, sys: 3.25 s, total: 24.9 s
# Wall time: 27min 39s

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance

# %% [markdown]
# Training losses and performance metrics are saved to Tensorboard and also to a logfile defined above with the **--name** flag when we train. In our case, we named this `yolov5s_results`. (If given no name, it defaults to `results.txt`.) The results file is plotted as a png after training completes.
#
# Note from Glenn: Partially completed `results.txt` files can be plotted with `from utils.utils import plot_results; plot_results()`.

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason...
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)  # view results.png

# %% [markdown]
# ### Curious? Visualize Our Training Data with Labels
#
# After training starts, view `train*.jpg` images to see training images, labels and augmentation effects.
#
# Note a mosaic dataloader is used for training (shown below), a new dataloading concept developed by Glenn Jocher and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
# first, display our ground truth data
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/val_batch0_labels.jpg', width=900)
# Out:
# GROUND TRUTH TRAINING DATA:

# %%
# print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/train_batch0.jpg', width=900)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:

# %% [markdown]
# #Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder downloaded from Roboflow.

# %%
# trained weights are saved by default in our weights folder
# %ls runs/
# Out:
# train/

# %%
# %ls runs/train/yolov5s_results/weights
# Out:
# best.pt  last.pt

# %%
# when we ran this, we saw .007 second inference time. That is 140 FPS on a TESLA P100!
# use the best weights!
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 640 --conf 0.4 --source /content/yolov5/Contrainer-Damage-Detection-2/test/images
# Out:
# /content/yolov5
# detect: weights=['runs/train/yolov5s_results/weights/best.pt'], source=/content/yolov5/Contrainer-Damage-Detection-2/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-227-ge4df1ec Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7251912 parameters, 0 gradients
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 285, in <module>
#     main(opt)
#   File "/content/yolov5/detect.py", line 280, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/yolov5/detect.py", line 114, in run
#     dataset = LoadImages(source, img_size=imgsz, stride=stride, auto=pt, vid_stride=vid_stride)
#   File "/content/yolov5/utils/dataloaders.py", line 254, in __init__
#     raise FileNotFoundError(f'{p} does not exist')
# FileNotFoundError: /content/yolov5/Contrainer-Damage-Detection-2/test/images does not exist

# %%
#display inference on ALL test images
#this looks much better with longer training above

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg')[0:10]: #assuming JPG #kita tampilkan 10 gambar saja
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# # Deploy Model Weights to Roboflow
#
# Now that you have trained your custom detector, you can upload it to Roboflow to deploy you model to a Hosted API and edge containers.

# %%
#project.version(dataset.version).deploy(model_type="yolov5", model_path=f"/content/yolov5/runs/train/yolov5s_results/")

# %%
#While your deployment is processing, checkout the deployment docs to take your model to most destinations https://docs.roboflow.com/inference

# %%
#Run inference on your model on a persistant, auto-scaling, cloud API
'''
#load model
model = project.version(dataset.version).model

#choose random test set image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
'''

# %% [markdown]
# ## Congrats!
#
# Hope you enjoyed this!
#
# --Team [Roboflow](https://roboflow.ai)
